# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7bf41fc3d9425f0dfc6d6dc443c166a5

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_descrip = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chifeng
# Processing Record 2 of Set 1 | kenitra
# Processing Record 3 of Set 1 | vage
# Processing Record 4 of Set 1 | doha
# Processing Record 5 of Set 1 | cidreira
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | hasaki
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | xingyi
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | ola
# Processing Record 16 of Set 1 | wanning
# Processing Record 17 of Set 1 | libertador general san martin
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | lalganj
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | tiksi
# Processing Record 23 of Set 1 | maniitsoq
# Processing Record 24 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 1 | svarstad
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | carnarvon
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | chokurdakh
# Processing Record 32 of Set 1 | itarema
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | saint-francois
# Processing Record 35 of Set 1 | chicama
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | dakar
# Processing Record 39 of Set 1 | selma
# Processing Record 40 of Set 1 | haines junction
# Processing Record 41 of Set 1 | san quintin
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | enshi
# Processing Record 44 of Set 1 | san cristobal
# Processing Record 45 of Set 1 | sakaiminato
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | praia da vitoria
# Processing Record 48 of Set 1 | waingapu
# Processing Record 49 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | mount isa
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | ankpa
# Processing Record 7 of Set 2 | komsomolskiy
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | araguatins
# City not found. Skipping...
# Processing Record 11 of Set 2 | zhigansk
# Processing Record 12 of Set 2 | leningradskiy
# Processing Record 13 of Set 2 | anadyr
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | yurga
# Processing Record 16 of Set 2 | baykit
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | zelenoborskiy
# Processing Record 19 of Set 2 | tura
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | nyrob
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | upernavik
# Processing Record 24 of Set 2 | troitsko-pechorsk
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | coromandel
# Processing Record 28 of Set 2 | ambilobe
# Processing Record 29 of Set 2 | morgaushi
# Processing Record 30 of Set 2 | natchitoches
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | bayshore gardens
# Processing Record 33 of Set 2 | coquimbo
# Processing Record 34 of Set 2 | pangnirtung
# Processing Record 35 of Set 2 | sun valley
# Processing Record 36 of Set 2 | severo-kurilsk
# Processing Record 37 of Set 2 | fairbanks
# Processing Record 38 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 2 | changli
# Processing Record 40 of Set 2 | mount gambier
# Processing Record 41 of Set 2 | shymkent
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | kashan
# Processing Record 44 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 2 | bandarbeyla
# Processing Record 46 of Set 2 | kargopol
# Processing Record 47 of Set 2 | thinadhoo
# Processing Record 48 of Set 2 | staraya poltavka
# Processing Record 49 of Set 2 | claveria
# Processing Record 50 of Set 2 | kourou
# Processing Record 1 of Set 3 | banjar
# Processing Record 2 of Set 3 | nabul
# City not found. Skipping...
# Processing Record 3 of Set 3 | dunmore town
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | opuwo
# Processing Record 6 of Set 3 | saint-pierre
# Processing Record 7 of Set 3 | waynesville
# Processing Record 8 of Set 3 | arrecife
# Processing Record 9 of Set 3 | benicarlo
# Processing Record 10 of Set 3 | moron
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | makakilo city
# Processing Record 13 of Set 3 | maraa
# Processing Record 14 of Set 3 | libreville
# Processing Record 15 of Set 3 | bethel
# Processing Record 16 of Set 3 | atar
# Processing Record 17 of Set 3 | east london
# Processing Record 18 of Set 3 | cabo san lucas
# Processing Record 19 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 3 | itapaci
# Processing Record 21 of Set 3 | padang
# Processing Record 22 of Set 3 | saldanha
# Processing Record 23 of Set 3 | alofi
# Processing Record 24 of Set 3 | port elizabeth
# Processing Record 25 of Set 3 | touros
# Processing Record 26 of Set 3 | nuuk
# Processing Record 27 of Set 3 | sioux lookout
# Processing Record 28 of Set 3 | qaanaaq
# Processing Record 29 of Set 3 | grand island
# Processing Record 30 of Set 3 | turukhansk
# Processing Record 31 of Set 3 | salalah
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | yar-sale
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | miramar
# Processing Record 37 of Set 3 | hobart
# Processing Record 38 of Set 3 | newberg
# Processing Record 39 of Set 3 | bambous virieux
# Processing Record 40 of Set 3 | cloppenburg
# Processing Record 41 of Set 3 | guicheng
# City not found. Skipping...
# Processing Record 42 of Set 3 | thunder bay
# Processing Record 43 of Set 3 | tortoli
# Processing Record 44 of Set 3 | pacific grove
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | huitziltepec
# Processing Record 47 of Set 3 | praya
# Processing Record 48 of Set 3 | vostok
# Processing Record 49 of Set 3 | burnie
# Processing Record 50 of Set 3 | ribeira grande
# Processing Record 1 of Set 4 | catamarca
# Processing Record 2 of Set 4 | maple creek
# Processing Record 3 of Set 4 | gat
# Processing Record 4 of Set 4 | mme
# City not found. Skipping...
# Processing Record 5 of Set 4 | kibre mengist
# Processing Record 6 of Set 4 | provideniya
# Processing Record 7 of Set 4 | isangel
# Processing Record 8 of Set 4 | kavaratti
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | paamiut
# Processing Record 11 of Set 4 | caravelas
# Processing Record 12 of Set 4 | sabzevar
# Processing Record 13 of Set 4 | gamboma
# Processing Record 14 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 4 | tezu
# Processing Record 17 of Set 4 | oktyabrskoye
# Processing Record 18 of Set 4 | sitka
# Processing Record 19 of Set 4 | san marcos
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | mwene-ditu
# Processing Record 23 of Set 4 | pevek
# Processing Record 24 of Set 4 | meulaboh
# Processing Record 25 of Set 4 | treinta y tres
# Processing Record 26 of Set 4 | slave lake
# Processing Record 27 of Set 4 | buraydah
# Processing Record 28 of Set 4 | buchanan
# Processing Record 29 of Set 4 | richards bay
# Processing Record 30 of Set 4 | seminole
# Processing Record 31 of Set 4 | stornoway
# Processing Record 32 of Set 4 | bojnurd
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 4 | yashkul
# Processing Record 36 of Set 4 | namibe
# Processing Record 37 of Set 4 | vila velha
# Processing Record 38 of Set 4 | adrar
# Processing Record 39 of Set 4 | avera
# Processing Record 40 of Set 4 | kavieng
# Processing Record 41 of Set 4 | tra vinh
# Processing Record 42 of Set 4 | tasiilaq
# Processing Record 43 of Set 4 | port lincoln
# Processing Record 44 of Set 4 | kruisfontein
# Processing Record 45 of Set 4 | rio gallegos
# Processing Record 46 of Set 4 | kieta
# Processing Record 47 of Set 4 | victoria
# Processing Record 48 of Set 4 | olafsvik
# Processing Record 49 of Set 4 | beringovskiy
# Processing Record 50 of Set 4 | bathsheba
# Processing Record 1 of Set 5 | yei
# Processing Record 2 of Set 5 | guerrero negro
# Processing Record 3 of Set 5 | zhanaozen
# Processing Record 4 of Set 5 | westport
# Processing Record 5 of Set 5 | college
# Processing Record 6 of Set 5 | krabi
# Processing Record 7 of Set 5 | gilroy
# Processing Record 8 of Set 5 | odesskoye
# Processing Record 9 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 5 | usinsk
# Processing Record 11 of Set 5 | cherskiy
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | brodick
# Processing Record 14 of Set 5 | faanui
# Processing Record 15 of Set 5 | vestmannaeyjar
# Processing Record 16 of Set 5 | robertsport
# Processing Record 17 of Set 5 | verkhoyansk
# Processing Record 18 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 5 | moree
# Processing Record 20 of Set 5 | saint george
# Processing Record 21 of Set 5 | mar del plata
# Processing Record 22 of Set 5 | namwala
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 5 | kaitangata
# Processing Record 26 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 5 | tuensang
# Processing Record 28 of Set 5 | okakarara
# Processing Record 29 of Set 5 | barcelona
# Processing Record 30 of Set 5 | aliwal north
# Processing Record 31 of Set 5 | vanimo
# Processing Record 32 of Set 5 | rovaniemi
# Processing Record 33 of Set 5 | nanortalik
# Processing Record 34 of Set 5 | laguna
# Processing Record 35 of Set 5 | arraial do cabo
# Processing Record 36 of Set 5 | qui nhon
# Processing Record 37 of Set 5 | fortuna
# Processing Record 38 of Set 5 | waitara
# Processing Record 39 of Set 5 | bosaso
# Processing Record 40 of Set 5 | douentza
# Processing Record 41 of Set 5 | dingle
# Processing Record 42 of Set 5 | port hedland
# Processing Record 43 of Set 5 | hamilton
# Processing Record 44 of Set 5 | antofagasta
# Processing Record 45 of Set 5 | besikduzu
# Processing Record 46 of Set 5 | chardara
# Processing Record 47 of Set 5 | mittagong
# Processing Record 48 of Set 5 | loveland
# Processing Record 49 of Set 5 | cayenne
# Processing Record 50 of Set 5 | kamenskiy
# Processing Record 1 of Set 6 | jamestown
# Processing Record 2 of Set 6 | hovd
# Processing Record 3 of Set 6 | kodinsk
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | san jose
# Processing Record 6 of Set 6 | jumla
# Processing Record 7 of Set 6 | pokhara
# Processing Record 8 of Set 6 | longonjo
# Processing Record 9 of Set 6 | puerto escondido
# Processing Record 10 of Set 6 | shingu
# Processing Record 11 of Set 6 | pell city
# Processing Record 12 of Set 6 | agadez
# Processing Record 13 of Set 6 | los llanos de aridane
# Processing Record 14 of Set 6 | pozoblanco
# Processing Record 15 of Set 6 | colares
# Processing Record 16 of Set 6 | camacha
# Processing Record 17 of Set 6 | vila
# Processing Record 18 of Set 6 | narsaq
# Processing Record 19 of Set 6 | kahului
# Processing Record 20 of Set 6 | broome
# Processing Record 21 of Set 6 | cochrane
# Processing Record 22 of Set 6 | ogdensburg
# Processing Record 23 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 24 of Set 6 | ostrovnoy
# Processing Record 25 of Set 6 | northam
# Processing Record 26 of Set 6 | cap-aux-meules
# Processing Record 27 of Set 6 | penzance
# Processing Record 28 of Set 6 | bossangoa
# Processing Record 29 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 6 | xinan
# Processing Record 31 of Set 6 | luderitz
# Processing Record 32 of Set 6 | thompson
# Processing Record 33 of Set 6 | luangwa
# Processing Record 34 of Set 6 | igarka
# Processing Record 35 of Set 6 | gelemso
# Processing Record 36 of Set 6 | galle
# Processing Record 37 of Set 6 | axim
# Processing Record 38 of Set 6 | xining
# Processing Record 39 of Set 6 | alyangula
# Processing Record 40 of Set 6 | chapais
# Processing Record 41 of Set 6 | luwuk
# Processing Record 42 of Set 6 | mudgal
# Processing Record 43 of Set 6 | cabrobo
# Processing Record 44 of Set 6 | san policarpo
# Processing Record 45 of Set 6 | bardiyah
# Processing Record 46 of Set 6 | mehamn
# Processing Record 47 of Set 6 | manado
# Processing Record 48 of Set 6 | seymchan
# Processing Record 49 of Set 6 | tanabe
# Processing Record 50 of Set 6 | meiganga
# Processing Record 1 of Set 7 | leua
# Processing Record 2 of Set 7 | portland
# Processing Record 3 of Set 7 | asyut
# Processing Record 4 of Set 7 | kungurtug
# Processing Record 5 of Set 7 | shieli
# Processing Record 6 of Set 7 | cap malheureux
# Processing Record 7 of Set 7 | saint charles
# Processing Record 8 of Set 7 | slupca
# Processing Record 9 of Set 7 | mitu
# Processing Record 10 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 7 | vao
# Processing Record 12 of Set 7 | oranjemund
# Processing Record 13 of Set 7 | emerald
# Processing Record 14 of Set 7 | pacifica
# Processing Record 15 of Set 7 | sur
# Processing Record 16 of Set 7 | camiri
# Processing Record 17 of Set 7 | deputatskiy
# Processing Record 18 of Set 7 | airai
# Processing Record 19 of Set 7 | ostersund
# Processing Record 20 of Set 7 | aklavik
# Processing Record 21 of Set 7 | sao filipe
# Processing Record 22 of Set 7 | balaipungut
# Processing Record 23 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 7 | hay river
# Processing Record 25 of Set 7 | trinidad
# Processing Record 26 of Set 7 | abha
# Processing Record 27 of Set 7 | mineiros
# Processing Record 28 of Set 7 | tabas
# Processing Record 29 of Set 7 | tual
# Processing Record 30 of Set 7 | takoradi
# Processing Record 31 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 7 | tombouctou
# Processing Record 33 of Set 7 | lompoc
# Processing Record 34 of Set 7 | dedza
# Processing Record 35 of Set 7 | xapuri
# Processing Record 36 of Set 7 | mingyue
# Processing Record 37 of Set 7 | hualmay
# Processing Record 38 of Set 7 | santa lucia
# Processing Record 39 of Set 7 | kosice
# Processing Record 40 of Set 7 | rantepao
# Processing Record 41 of Set 7 | coahuayana
# Processing Record 42 of Set 7 | pimenteiras
# Processing Record 43 of Set 7 | tankhoy
# Processing Record 44 of Set 7 | oranjestad
# Processing Record 45 of Set 7 | katsuura
# Processing Record 46 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 47 of Set 7 | san pedro
# Processing Record 48 of Set 7 | carahue
# Processing Record 49 of Set 7 | luganville
# Processing Record 50 of Set 7 | pauini
# Processing Record 1 of Set 8 | carikar
# City not found. Skipping...
# Processing Record 2 of Set 8 | seoul
# Processing Record 3 of Set 8 | belaguntha
# Processing Record 4 of Set 8 | cockburn town
# Processing Record 5 of Set 8 | fuling
# Processing Record 6 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 8 | ryde
# Processing Record 8 of Set 8 | narasannapeta
# Processing Record 9 of Set 8 | zhicheng
# Processing Record 10 of Set 8 | ixtapa
# Processing Record 11 of Set 8 | kharan
# Processing Record 12 of Set 8 | mehran
# Processing Record 13 of Set 8 | muravlenko
# Processing Record 14 of Set 8 | san roque
# Processing Record 15 of Set 8 | nome
# Processing Record 16 of Set 8 | chara
# Processing Record 17 of Set 8 | foumban
# Processing Record 18 of Set 8 | jyvaskyla
# Processing Record 19 of Set 8 | lebu
# Processing Record 20 of Set 8 | mildura
# Processing Record 21 of Set 8 | chiapilla
# Processing Record 22 of Set 8 | ajdabiya
# Processing Record 23 of Set 8 | quatre cocos
# Processing Record 24 of Set 8 | kharp
# Processing Record 25 of Set 8 | abu samrah
# Processing Record 26 of Set 8 | zaysan
# Processing Record 27 of Set 8 | shimoda
# Processing Record 28 of Set 8 | gornopravdinsk
# Processing Record 29 of Set 8 | jiangkou
# Processing Record 30 of Set 8 | vila franca do campo
# Processing Record 31 of Set 8 | kutum
# Processing Record 32 of Set 8 | hangu
# Processing Record 33 of Set 8 | gamba
# Processing Record 34 of Set 8 | andapa
# Processing Record 35 of Set 8 | loandjili
# Processing Record 36 of Set 8 | palmer
# Processing Record 37 of Set 8 | rosetta
# Processing Record 38 of Set 8 | ocna mures
# Processing Record 39 of Set 8 | lorengau
# Processing Record 40 of Set 8 | pombia
# Processing Record 41 of Set 8 | kamiiso
# Processing Record 42 of Set 8 | clyde river
# Processing Record 43 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 8 | hambantota
# Processing Record 45 of Set 8 | bud
# Processing Record 46 of Set 8 | novobessergenevka
# Processing Record 47 of Set 8 | sri aman
# Processing Record 48 of Set 8 | ancud
# Processing Record 49 of Set 8 | baculin
# Processing Record 50 of Set 8 | uyar
# Processing Record 1 of Set 9 | ronneby
# Processing Record 2 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 3 of Set 9 | bilibino
# Processing Record 4 of Set 9 | lata
# Processing Record 5 of Set 9 | surt
# Processing Record 6 of Set 9 | pinhao
# Processing Record 7 of Set 9 | talnakh
# Processing Record 8 of Set 9 | marigot
# Processing Record 9 of Set 9 | pakokku
# Processing Record 10 of Set 9 | port blair
# Processing Record 11 of Set 9 | yinchuan
# Processing Record 12 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 13 of Set 9 | narodychi
# Processing Record 14 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 15 of Set 9 | berekua
# Processing Record 16 of Set 9 | kaliganj
# Processing Record 17 of Set 9 | manokwari
# Processing Record 18 of Set 9 | anito
# Processing Record 19 of Set 9 | tonota
# Processing Record 20 of Set 9 | bairiki
# Processing Record 21 of Set 9 | svetlogorsk
# Processing Record 22 of Set 9 | camana
# Processing Record 23 of Set 9 | ternate
# Processing Record 24 of Set 9 | kindu
# Processing Record 25 of Set 9 | ergani
# Processing Record 26 of Set 9 | buxtehude
# Processing Record 27 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 9 | jining
# Processing Record 29 of Set 9 | noumea
# Processing Record 30 of Set 9 | pueblo nuevo
# Processing Record 31 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 32 of Set 9 | tarko-sale
# Processing Record 33 of Set 9 | port moresby
# Processing Record 34 of Set 9 | taoudenni
# Processing Record 35 of Set 9 | trincomalee
# Processing Record 36 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 37 of Set 9 | linxia
# Processing Record 38 of Set 9 | heinola
# Processing Record 39 of Set 9 | joshimath
# Processing Record 40 of Set 9 | yumen
# Processing Record 41 of Set 9 | umm lajj
# Processing Record 42 of Set 9 | tuatapere
# Processing Record 43 of Set 9 | khatanga
# Processing Record 44 of Set 9 | haapsalu
# Processing Record 45 of Set 9 | saint-louis
# Processing Record 46 of Set 9 | kropotkin
# Processing Record 47 of Set 9 | miri
# Processing Record 48 of Set 9 | chake chake
# Processing Record 49 of Set 9 | kununurra
# Processing Record 50 of Set 9 | grindavik
# Processing Record 1 of Set 10 | castro
# Processing Record 2 of Set 10 | tuy hoa
# Processing Record 3 of Set 10 | vagamo
# Processing Record 4 of Set 10 | ahipara
# Processing Record 5 of Set 10 | norman wells
# Processing Record 6 of Set 10 | maumere
# Processing Record 7 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 10 | tamworth
# Processing Record 9 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 10 of Set 10 | vardo
# Processing Record 11 of Set 10 | talcahuano
# Processing Record 12 of Set 10 | ladario
# Processing Record 13 of Set 10 | padampur
# Processing Record 14 of Set 10 | torbay
# Processing Record 15 of Set 10 | xiangxiang
# Processing Record 16 of Set 10 | nesna
# Processing Record 17 of Set 10 | louis trichardt
# Processing Record 18 of Set 10 | daru
# Processing Record 19 of Set 10 | kifri
# Processing Record 20 of Set 10 | nelson bay
# Processing Record 21 of Set 10 | piranhas
# Processing Record 22 of Set 10 | berlevag
# Processing Record 23 of Set 10 | egvekinot
# Processing Record 24 of Set 10 | lagoa
# Processing Record 25 of Set 10 | sao raimundo nonato
# Processing Record 26 of Set 10 | hereford
# Processing Record 27 of Set 10 | manggar
# Processing Record 28 of Set 10 | polyarnyy
# Processing Record 29 of Set 10 | multan
# Processing Record 30 of Set 10 | chauk
# Processing Record 31 of Set 10 | la romana
# Processing Record 32 of Set 10 | springdale
# Processing Record 33 of Set 10 | along
# Processing Record 34 of Set 10 | marawi
# Processing Record 35 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 36 of Set 10 | bangassou
# Processing Record 37 of Set 10 | copacabana
# Processing Record 38 of Set 10 | saint anthony
# Processing Record 39 of Set 10 | derzhavinsk
# Processing Record 40 of Set 10 | acarau
# Processing Record 41 of Set 10 | marovoay
# Processing Record 42 of Set 10 | sampit
# Processing Record 43 of Set 10 | sabang
# Processing Record 44 of Set 10 | tandalti
# Processing Record 45 of Set 10 | grand gaube
# Processing Record 46 of Set 10 | ikom
# Processing Record 47 of Set 10 | benghazi
# Processing Record 48 of Set 10 | pitimbu
# Processing Record 49 of Set 10 | jeremoabo
# Processing Record 50 of Set 10 | sindor
# Processing Record 1 of Set 11 | lima
# Processing Record 2 of Set 11 | taltal
# Processing Record 3 of Set 11 | saint marys
# Processing Record 4 of Set 11 | nhulunbuy
# Processing Record 5 of Set 11 | nemuro
# Processing Record 6 of Set 11 | balkhash
# Processing Record 7 of Set 11 | bukama
# Processing Record 8 of Set 11 | molave
# Processing Record 9 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 10 of Set 11 | kaithal
# Processing Record 11 of Set 11 | fatezh
# Processing Record 12 of Set 11 | muisne
# Processing Record 13 of Set 11 | ohara
# Processing Record 14 of Set 11 | jiangyou
# Processing Record 15 of Set 11 | angoram
# Processing Record 16 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 11 | merauke
# Processing Record 18 of Set 11 | lewistown
# Processing Record 19 of Set 11 | imeni poliny osipenko
# Processing Record 20 of Set 11 | pemberton
# Processing Record 21 of Set 11 | yulara
# Processing Record 22 of Set 11 | duayaw nkwanta
# Processing Record 23 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 24 of Set 11 | abu dhabi
# Processing Record 25 of Set 11 | aswan
# Processing Record 26 of Set 11 | sembakung
# Processing Record 27 of Set 11 | cascioarele
# Processing Record 28 of Set 11 | rodbyhavn
# Processing Record 29 of Set 11 | yibin
# Processing Record 30 of Set 11 | harper
# Processing Record 31 of Set 11 | porbandar
# Processing Record 32 of Set 11 | kampene
# Processing Record 33 of Set 11 | shache
# Processing Record 34 of Set 11 | west bay
# Processing Record 35 of Set 11 | lieksa
# Processing Record 36 of Set 11 | klaksvik
# Processing Record 37 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 11 | mtimbira
# Processing Record 39 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 11 | bambanglipuro
# Processing Record 41 of Set 11 | athabasca
# Processing Record 42 of Set 11 | guane
# Processing Record 43 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 11 | kanlagay
# Processing Record 45 of Set 11 | boa vista
# Processing Record 46 of Set 11 | santiago del estero
# Processing Record 47 of Set 11 | ugoofaaru
# Processing Record 48 of Set 11 | phrai bung
# City not found. Skipping...
# Processing Record 49 of Set 11 | amahai
# Processing Record 50 of Set 11 | erdenet
# Processing Record 1 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 2 of Set 12 | korla
# Processing Record 3 of Set 12 | quesnel
# Processing Record 4 of Set 12 | salinas
# Processing Record 5 of Set 12 | cangzhou
# Processing Record 6 of Set 12 | north platte
# Processing Record 7 of Set 12 | maragogi
# Processing Record 8 of Set 12 | port macquarie
# Processing Record 9 of Set 12 | fredericksburg
# Processing Record 10 of Set 12 | ngaoundere
# Processing Record 11 of Set 12 | bilma
# Processing Record 12 of Set 12 | havoysund
# Processing Record 13 of Set 12 | faya
# Processing Record 14 of Set 12 | morgantown
# Processing Record 15 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 16 of Set 12 | kigoma
# Processing Record 17 of Set 12 | kaspiysk
# Processing Record 18 of Set 12 | greymouth
# Processing Record 19 of Set 12 | nova olimpia
# Processing Record 20 of Set 12 | pohrebyshche
# Processing Record 21 of Set 12 | hirado
# Processing Record 22 of Set 12 | pepel
# Processing Record 23 of Set 12 | marathon
# Processing Record 24 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 12 | pisco
# Processing Record 26 of Set 12 | fraga
# Processing Record 27 of Set 12 | angahuan
# Processing Record 28 of Set 12 | sao sebastiao do paraiso
# Processing Record 29 of Set 12 | la quinta
# Processing Record 30 of Set 12 | batken
# Processing Record 31 of Set 12 | hun
# Processing Record 32 of Set 12 | najran
# Processing Record 33 of Set 12 | lazaro cardenas
# Processing Record 34 of Set 12 | mwinilunga
# Processing Record 35 of Set 12 | charters towers
# Processing Record 36 of Set 12 | itaueira
# Processing Record 37 of Set 12 | srandakan
# Processing Record 38 of Set 12 | newport
# Processing Record 39 of Set 12 | roswell
# Processing Record 40 of Set 12 | south lake tahoe
# Processing Record 41 of Set 12 | molteno
# Processing Record 42 of Set 12 | adiake
# Processing Record 43 of Set 12 | sabha
# Processing Record 44 of Set 12 | tecoanapa
# Processing Record 45 of Set 12 | kamakwie
# Processing Record 46 of Set 12 | antalaha
# Processing Record 47 of Set 12 | mnogovershinnyy
# Processing Record 48 of Set 12 | vasudevanallur
# Processing Record 49 of Set 12 | puerto colombia
# Processing Record 50 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 1 of Set 13 | keita
# Processing Record 2 of Set 13 | hami
# Processing Record 3 of Set 13 | kashi
# Processing Record 4 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 13 | ishigaki
# Processing Record 6 of Set 13 | onega
# Processing Record 7 of Set 13 | mandera
# Processing Record 8 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 13 | playas
# Processing Record 10 of Set 13 | marzuq
# Processing Record 11 of Set 13 | sokoni
# Processing Record 12 of Set 13 | anori
# Processing Record 13 of Set 13 | havre-saint-pierre
# Processing Record 14 of Set 13 | agde
# Processing Record 15 of Set 13 | yenagoa
# Processing Record 16 of Set 13 | teguise
# Processing Record 17 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 13 | hearst
# Processing Record 19 of Set 13 | xai-xai
# Processing Record 20 of Set 13 | ciudad bolivar
# Processing Record 21 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 22 of Set 13 | darnah
# Processing Record 23 of Set 13 | labuhan
# Processing Record 24 of Set 13 | aljezur
# Processing Record 25 of Set 13 | sanok
# Processing Record 26 of Set 13 | ponta delgada
# Processing Record 27 of Set 13 | mareeba
# Processing Record 28 of Set 13 | kandrian
# Processing Record 29 of Set 13 | tuymazy
# Processing Record 30 of Set 13 | muhos
# Processing Record 31 of Set 13 | semiletka
# Processing Record 32 of Set 13 | janakpur
# Processing Record 33 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 13 | edendale
# Processing Record 35 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 13 | waynesboro
# Processing Record 37 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 13 | belmonte
# Processing Record 39 of Set 13 | timbiqui
# Processing Record 40 of Set 13 | kamenka
# Processing Record 41 of Set 13 | arkhara
# Processing Record 42 of Set 13 | boquira
# Processing Record 43 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 44 of Set 13 | cape elizabeth
# City not found. Skipping...
# Processing Record 45 of Set 13 | nyurba
# Processing Record 46 of Set 13 | santiago
# Processing Record 47 of Set 13 | caborca
# Processing Record 48 of Set 13 | sinnamary
# Processing Record 49 of Set 13 | tazovskiy
# Processing Record 50 of Set 13 | raga
# Processing Record 1 of Set 14 | noshiro
# Processing Record 2 of Set 14 | impfondo
# Processing Record 3 of Set 14 | barkhan
# Processing Record 4 of Set 14 | huarmey
# Processing Record 5 of Set 14 | jimenez
# Processing Record 6 of Set 14 | te anau
# Processing Record 7 of Set 14 | ilinskiy
# Processing Record 8 of Set 14 | siparia
# Processing Record 9 of Set 14 | esperance
# Processing Record 10 of Set 14 | changping
# Processing Record 11 of Set 14 | stromness
# Processing Record 12 of Set 14 | kombissiri
# Processing Record 13 of Set 14 | dukat
# Processing Record 14 of Set 14 | karwar
# Processing Record 15 of Set 14 | pandan
# Processing Record 16 of Set 14 | barra patuca
# Processing Record 17 of Set 14 | elko
# Processing Record 18 of Set 14 | margate
# Processing Record 19 of Set 14 | kalmunai
# Processing Record 20 of Set 14 | north bend
# Processing Record 21 of Set 14 | vendome
# Processing Record 22 of Set 14 | kushiro
# Processing Record 23 of Set 14 | broken hill
# Processing Record 24 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 14 | ayan
# Processing Record 26 of Set 14 | ust-tsilma
# Processing Record 27 of Set 14 | viedma
# Processing Record 28 of Set 14 | hinton
# Processing Record 29 of Set 14 | anloga
# Processing Record 30 of Set 14 | campina verde
# Processing Record 31 of Set 14 | kuching
# Processing Record 32 of Set 14 | ananas
# Processing Record 33 of Set 14 | dunedin
# Processing Record 34 of Set 14 | kasongo-lunda
# Processing Record 35 of Set 14 | ontario
# Processing Record 36 of Set 14 | khuzdar
# Processing Record 37 of Set 14 | ocampo
# Processing Record 38 of Set 14 | manacor
# Processing Record 39 of Set 14 | olinda
# Processing Record 40 of Set 14 | mhlume
# Processing Record 41 of Set 14 | tomarovka
# Processing Record 42 of Set 14 | ludgerovice
# Processing Record 43 of Set 14 | angra
# City not found. Skipping...
# Processing Record 44 of Set 14 | benguela
# Processing Record 45 of Set 14 | pimenta bueno
# Processing Record 46 of Set 14 | sayyan
# Processing Record 47 of Set 14 | baghdad
# Processing Record 48 of Set 14 | bashtanka
# Processing Record 49 of Set 14 | mogadishu
# Processing Record 50 of Set 14 | valparaiso
# Processing Record 1 of Set 15 | uruguaiana
# Processing Record 2 of Set 15 | smiltene
# Processing Record 3 of Set 15 | yumbel
# Processing Record 4 of Set 15 | demba
# Processing Record 5 of Set 15 | cozumel
# Processing Record 6 of Set 15 | governador valadares
# Processing Record 7 of Set 15 | cape canaveral
# Processing Record 8 of Set 15 | marakkanam
# Processing Record 9 of Set 15 | muros
# Processing Record 10 of Set 15 | baker city
# Processing Record 11 of Set 15 | henties bay
# Processing Record 12 of Set 15 | darien
# Processing Record 13 of Set 15 | andros town
# Processing Record 14 of Set 15 | samarai
# Processing Record 15 of Set 15 | sao gabriel da cachoeira
# Processing Record 16 of Set 15 | sola
# Processing Record 17 of Set 15 | flin flon
# Processing Record 18 of Set 15 | mitsamiouli
# Processing Record 19 of Set 15 | port hueneme
# Processing Record 20 of Set 15 | srednekolymsk
# Processing Record 21 of Set 15 | tunggol
# Processing Record 22 of Set 15 | amapa
# Processing Record 23 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 15 | muncar
# Processing Record 25 of Set 15 | cortez
# Processing Record 26 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 15 | gombong
# Processing Record 28 of Set 15 | manakara
# Processing Record 29 of Set 15 | forestville
# Processing Record 30 of Set 15 | kismayo
# Processing Record 31 of Set 15 | amurzet
# Processing Record 32 of Set 15 | ipinda
# Processing Record 33 of Set 15 | wewak
# Processing Record 34 of Set 15 | naze
# Processing Record 35 of Set 15 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 36 of Set 15 | astipalaia
# City not found. Skipping...
# Processing Record 37 of Set 15 | ust-nera
# Processing Record 38 of Set 15 | ilhabela
# Processing Record 39 of Set 15 | popondetta
# Processing Record 40 of Set 15 | nador
# Processing Record 41 of Set 15 | glendive
# Processing Record 42 of Set 15 | mongu
# Processing Record 43 of Set 15 | inirida
# Processing Record 44 of Set 15 | alamosa
# Processing Record 45 of Set 15 | sinnar
# Processing Record 46 of Set 15 | hoeilaart
# Processing Record 47 of Set 15 | matara
# Processing Record 48 of Set 15 | ketou
# Processing Record 49 of Set 15 | dibai
# Processing Record 50 of Set 15 | katangli
# Processing Record 1 of Set 16 | morris
# Processing Record 2 of Set 16 | nouadhibou
# Processing Record 3 of Set 16 | buenos aires
# Processing Record 4 of Set 16 | daitari
# Processing Record 5 of Set 16 | copiapo
# Processing Record 6 of Set 16 | belle fourche
# Processing Record 7 of Set 16 | bubaque
# Processing Record 8 of Set 16 | angoche
# Processing Record 9 of Set 16 | ipameri
# Processing Record 10 of Set 16 | nieuw amsterdam
# Processing Record 11 of Set 16 | aripuana
# Processing Record 12 of Set 16 | mamou
# Processing Record 13 of Set 16 | basco
# Processing Record 14 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 16 | walvis bay
# Processing Record 16 of Set 16 | gigmoto
# Processing Record 17 of Set 16 | inderborskiy
# City not found. Skipping...
# Processing Record 18 of Set 16 | aketi
# Processing Record 19 of Set 16 | lakeville
# Processing Record 20 of Set 16 | sokoto
# Processing Record 21 of Set 16 | scalea
# Processing Record 22 of Set 16 | jagannathpur
# Processing Record 23 of Set 16 | strezhevoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Chifeng  42.2683  118.9636     36.23        76         100
# 1       Kenitra  34.2610   -6.5802     64.72        88          32
# 2          Vage  60.0469    5.5178     51.51        92         100
# 3          Doha  25.2867   51.5333     80.49        79           0
# 4      Cidreira -30.1811  -50.2056     67.84        88          32
# 5          Chuy -33.6971  -53.4616     64.85        89          45
# 6  Punta Arenas -53.1500  -70.9167     48.31        53           0
# 7        Hasaki  35.7333  140.8333     61.29        67          86
# 8   New Norfolk -42.7826  147.0587     58.91        51          93
# 9        Xingyi  24.1877  102.8170     57.33        98          99
#
#    Wind Speed Country Current Description
# 0        8.48      CN     overcast clouds
# 1        7.09      MA    scattered clouds
# 2       11.83      NO     overcast clouds
# 3        2.30      QA           clear sky
# 4       22.06      BR    scattered clouds
# 5       11.79      UY    scattered clouds
# 6       13.80      CL           clear sky
# 7        9.55      JP       moderate rain
# 8        4.00      AU     overcast clouds
# 9        3.15      CN     overcast clouds

# %%
#Reorder the columns.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
#Display DataFrame with columns in desired order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Chifeng      CN  42.2683  118.9636     36.23        76         100
# 1       Kenitra      MA  34.2610   -6.5802     64.72        88          32
# 2          Vage      NO  60.0469    5.5178     51.51        92         100
# 3          Doha      QA  25.2867   51.5333     80.49        79           0
# 4      Cidreira      BR -30.1811  -50.2056     67.84        88          32
# 5          Chuy      UY -33.6971  -53.4616     64.85        89          45
# 6  Punta Arenas      CL -53.1500  -70.9167     48.31        53           0
# 7        Hasaki      JP  35.7333  140.8333     61.29        67          86
# 8   New Norfolk      AU -42.7826  147.0587     58.91        51          93
# 9        Xingyi      CN  24.1877  102.8170     57.33        98          99
#
#    Wind Speed Current Description
# 0        8.48     overcast clouds
# 1        7.09    scattered clouds
# 2       11.83     overcast clouds
# 3        2.30           clear sky
# 4       22.06    scattered clouds
# 5       11.79    scattered clouds
# 6       13.80           clear sky
# 7        9.55       moderate rain
# 8        4.00     overcast clouds
# 9        3.15     overcast clouds

# %%
#Formatting
city_data_df['Lat'] = city_data_df['Lat'].map("{:.2f}".format)
city_data_df['Lng'] = city_data_df['Lng'].map("{:.2f}".format)
city_data_df.head(10)
# Out:
#            City Country     Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Chifeng      CN   42.27  118.96     36.23        76         100
# 1       Kenitra      MA   34.26   -6.58     64.72        88          32
# 2          Vage      NO   60.05    5.52     51.51        92         100
# 3          Doha      QA   25.29   51.53     80.49        79           0
# 4      Cidreira      BR  -30.18  -50.21     67.84        88          32
# 5          Chuy      UY  -33.70  -53.46     64.85        89          45
# 6  Punta Arenas      CL  -53.15  -70.92     48.31        53           0
# 7        Hasaki      JP   35.73  140.83     61.29        67          86
# 8   New Norfolk      AU  -42.78  147.06     58.91        51          93
# 9        Xingyi      CN   24.19  102.82     57.33        98          99
#
#    Wind Speed Current Description
# 0        8.48     overcast clouds
# 1        7.09    scattered clouds
# 2       11.83     overcast clouds
# 3        2.30           clear sky
# 4       22.06    scattered clouds
# 5       11.79    scattered clouds
# 6       13.80           clear sky
# 7        9.55       moderate rain
# 8        4.00     overcast clouds
# 9        3.15     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
